# %%
API_KEY = '21c044c9-f99f-4349-8fe8-e8f84073b5da'
API_ENDPOINT_SANDBOX = 'sandbox-api.coinmarketcap.com'

# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = f'https://{API_ENDPOINT_SANDBOX}/v1/cryptocurrency/quotes/latest'
parameters = {
  'symbol':'BTC,XRP,ETH,LTC,ZEN,POLIS'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': API_KEY,
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data['data'])
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'BTC': {'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 7861, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 17889837, 'total_supply': 17889837, 'is_market_cap_included_in_calc': 1, 'platform': None, 'cmc_rank': 1, 'last_updated': '2019-08-22T04:25:31.000Z', 'quote': {'USD': {'price': 9969.23023474, 'volume_24h': 17753272722.3099, 'percent_change_1h': 0.270476, 'percent_change_24h': -4.05996, 'percent_change_7d': 0.0343581, 'market_cap': 178347903914.97034, 'last_updated': '2019-08-22T04:25:31.000Z'}}}, 'ETH': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 5588, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': None, 'circulating_supply': 107420988.249, 'total_supply': 107420988.249, 'is_market_cap_included_in_calc': 1, 'platform': None, 'cmc_rank': 2, 'last_updated': '2019-08-22T04:25:21.000Z', 'quote': {'USD': {'p
# ...

# %%
def div_mil_n_vezes(valor):
    n=0
    while(valor > 1000):
        valor /= 1000
        n+= 1
    return valor, n
    

def ajusta_escala(valor):
    valor, n = div_mil_n_vezes(valor)
    return (round(valor,3), n)


def formata_volume(vol):

    escala_grandeza = ['','Mil','Milhões','Bilhões','Trilhões']
    
    valor,indice = ajusta_escala(round(vol))
    
    return str(valor) + ' ' + escala_grandeza[indice]


def mostra_cotacao(cotacoes):
    if type(cotacoes) is not dict:
        print('cotacoes não é dict.')
        return None
    for moeda,info in cotacoes.items():
        print(f"PREÇO: {round(info['price'],3)} {moeda}")
        print(f"VOLUME: {formata_volume(info['volume_24h'])} {moeda}")
        print()
              
        
for crypto,info in data['data'].items():
    print(f'{crypto}:')
    mostra_cotacao(info['quote'])


print(f"ATUALIZADO: {info['last_updated'].split('T')[0]}")
# Out:
# BTC:
# PREÇO: 9969.23 USD
# VOLUME: 17.753 Bilhões USD
#
# ETH:
# PREÇO: 185.064 USD
# VOLUME: 6.939 Bilhões USD
#
# LTC:
# PREÇO: 71.756 USD
# VOLUME: 2.549 Bilhões USD
#
# POLIS:
# PREÇO: 0.541 USD
# VOLUME: 7.43 Mil USD
#
# XRP:
# PREÇO: 0.264 USD
# VOLUME: 905.918 Milhões USD
#
# ZEN:
# PREÇO: 5.034 USD
# VOLUME: 2.129 Milhões USD
#
# ATUALIZADO: 2019-08-22

# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = f'https://{API_ENDPOINT_SANDBOX}/v1/cryptocurrency/map'
parameters = {
  'symbol':'BTC,XRP,POLIS'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': API_KEY,
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2019-08-25T01:30:12.821Z', 'error_code': 0, 'error_message': None, 'elapsed': 5, 'credit_count': 1}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'is_active': 1, 'rank': 1, 'first_historical_data': '2019-08-06T00:04:02.000Z', 'last_historical_data': '2019-08-22T04:19:02.000Z', 'platform': None}, {'id': 2359, 'name': 'Polis', 'symbol': 'POLIS', 'slug': 'polis', 'is_active': 1, 'rank': 717, 'first_historical_data': '2019-08-06T00:04:05.000Z', 'last_historical_data': '2019-08-22T04:19:08.000Z', 'platform': None}, {'id': 52, 'name': 'XRP', 'symbol': 'XRP', 'slug': 'ripple', 'is_active': 1, 'rank': 3, 'first_historical_data': '2019-08-06T00:04:02.000Z', 'last_historical_data': '2019-08-22T04:19:02.000Z', 'platform': None}]}

# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'symbol':'XRP',
  'limit':'2',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '21c044c9-f99f-4349-8fe8-e8f84073b5da',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2019-08-25T01:27:28.963Z', 'error_code': 400, 'error_message': '"symbol" is not allowed', 'elapsed': 0, 'credit_count': 0}}

# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '21c044c9-f99f-4349-8fe8-e8f84073b5da',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2019-08-25T01:22:50.648Z', 'error_code': 0, 'error_message': None, 'elapsed': 301, 'credit_count': 12}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 7861, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 17889837, 'total_supply': 17889837, 'platform': None, 'cmc_rank': 1, 'last_updated': '2019-08-22T04:25:31.000Z', 'quote': {'USD': {'price': 9969.23023474, 'volume_24h': 17753272722.3099, 'percent_change_1h': 0.270476, 'percent_change_24h': -4.05996, 'percent_change_7d': 0.0343581, 'market_cap': 178347903914.97034, 'last_updated': '2019-08-22T04:25:31.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 5588, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': None, 'circulating_supply': 107420988.249, 'total_supply': 107420988.249, 'platform': None, 'cmc_rank': 2, 'last_updated'
# ...
